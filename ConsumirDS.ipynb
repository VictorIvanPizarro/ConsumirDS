# %%
import pandas as pd

url = "C:\\Users\\Campus FP\\Desktop\\prueba.csv"
df = pd.read_csv(url)
df.plot(kind ="hist",  y="Population", title="visitas")
# Out:
# <AxesSubplot:title={'center':'visitas'}, ylabel='Frequency'>

# %%
import pandas as pd

url = "C:\\Users\\Campus FP\\Desktop\\diamonds.csv"
df = pd.read_csv(url)
df.plot(kind ="hist",  y="price", title="visitas")
# Out:
# <AxesSubplot:title={'center':'visitas'}, ylabel='Frequency'>
